# %%
import numpy as np
import random
import matplotlib.pyplot as plt
x= np.random.randint(0,50,(100))
c= np.random.randint(0,20,(100))
y= []
for i in range(100):
    k= 3*x[i] + c[i] 
    y.append(k)
plt.scatter(x,y)
